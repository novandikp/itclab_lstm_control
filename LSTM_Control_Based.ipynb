# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
import time
from tqdm import tqdm # Progress bar

# For scaling, feature selection
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.model_selection import train_test_split 

# For LSTM model
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense
from keras.callbacks import EarlyStopping
from tqdm.keras import TqdmCallback
from keras.models import load_model

# For TCLab
import tclab

# For itclab
import itclab

# %% [markdown]
# # Initialize TCLab Emulator with 100x speedup for data collection

# %%
speedup = 100
TCLab = tclab.setup(connected=False, speedup = speedup)

# %% [markdown]
# ### PID controller

# %%
# PID Parameters
Kc   = 6.0
tauI = 75.0 # sec
tauD = 0.0  # sec

#-----------------------------------------
# PID Controller
#-----------------------------------------

def pid(sp,pv,pv_last,ierr,dt):
    # PID coefficients in terms of tuning parameters
    KP = Kc
    KI = Kc / tauI
    KD = Kc * tauD
    
    # ubias for controller (initial heater)
    op0 = 0 
    
    # upper and lower bounds on heater level
    ophi = 100
    oplo = 0
    
    # calculate the error
    error = sp - pv
    
    # calculate the integral error
    ierr = ierr + KI * error * dt
    
    # calculate the measurement derivative
    if dt>=1e-8:
        dpv = (pv - pv_last) / dt
    else:
        dpv = 0.0;
    
    # calculate the PID output
    P = KP * error
    I = ierr
    D = -KD * dpv
    op = op0 + P + I + D
    
    # implement anti-reset windup
    if op < oplo or op > ophi:
        I = I - KI * error * dt
        # clip output
        op = max(oplo,min(ophi,op))
        
    # return the controller output and PID terms
    return [op,P,I,D]

# %% [markdown]
# ### Generate data for training LSTM

# %%
##### Set up run parameters #####
# Run time in minutes
run_time = 90.0

# Number of cycles
loops = int(60.0*run_time)

# arrays for storing data
T1 = np.zeros(loops) # measured T (degC)
Q1 = np.zeros(loops) # Heater values
tm = np.zeros(loops) # Time

# Temperature set point (degC)
with TCLab() as lab:
    Tsp1 = np.ones(loops) * lab.T1

# vary temperature setpoint
end = 30 # leave 1st 30 seconds of temp set point as room temp
while end <= loops:
    start = end
    # keep new temp set point value for anywhere from 4 to 10 min
    end += random.randint(240,600)
    Tsp1[start:end] = random.randint(30,70)

# Plot
plt.plot(Tsp1)
plt.xlabel('Time',size=14)
plt.ylabel(r'Temp SP ($^oC$)',size=14)
plt.xticks(size=12)
plt.yticks(size=12)
plt.savefig('SP_profile.png');

# %% [markdown]
# ### Data Collection

# %%
# Data collection
with TCLab() as lab:
    # Find current T1, T2
    print('Temperature 1: {0:0.2f} °C'.format(lab.T1))
    print('Temperature 2: {0:0.2f} °C'.format(lab.T2))

    # Integral error
    ierr = 0.0
    # Integral absolute error
    iae = 0.0
    
    prev_time = 0
    for i,t in enumerate(tclab.clock(loops-1)):
        tm[i] = t
        dt = t - prev_time
        
        # Read temperatures in Kelvin 
        T1[i] = lab.T1

        # Integral absolute error
        iae += np.abs(Tsp1[i]-T1[i])

        # Calculate PID output
        [Q1[i],P,ierr,D] = pid(Tsp1[i],T1[i],T1[i-1],ierr,dt)
        
        # Calculate MPC output (optionally replace PID)

        # Write heater output (0-100)
        lab.Q1(Q1[i])

        # Print line of data
        if i%100==0:
            print(('{:6.1f} {:6.2f} {:6.2f} ' + \
                  '{:6.2f} {:6.2f} {:6.2f} {:6.2f} {:6.2f}').format( \
# 3922.0  53.00  51.25  55.16  10.53  44.63  -0.00 12063.92
# 4022.0  53.00  52.86  54.14   0.86  53.28  -0.00 12171.99
# 4122.0  53.00  52.86  54.51   0.86  53.65  -0.00 12187.37
# 4222.0  53.00  52.86  54.52   0.86  53.66   0.00 12203.26
# 4322.0  53.00  52.86  54.52   0.86  53.67  -0.00 12219.16
# 4422.0  44.00  48.99   8.89 -29.94  38.82  -0.00 12495.01
# 4522.0  44.00  42.87  42.25   6.80  35.45   0.00 12635.28
# 4622.0  44.00  44.16  37.76  -0.93  38.69  -0.00 12676.16
# 4722.0  44.00  44.16  37.70  -0.93  38.63  -0.00 12692.23
# 4822.0  48.00  47.70  52.13   1.80  50.34  -0.00 12844.44
# 4922.0  48.00  48.34  44.19  -2.07  46.26  -0.00 12895.38
# 5022.0  48.00  48.02  45.30  -0.14  45.43  -0.00 12905.70
# 5122.0  48.00  48.02  45.12  -0.14  45.25  -0.00 12907.97
# 5222.0  48.00  47.70  46.95   1.80  45.15   0.00 12911.08
# 5322.0  48.00  48.02  45.09  -0.14  45.22  -0.00 12916.11
# TCLab Model disconnected successfully.

# %%
df = pd.DataFrame()
df['Q1'] = Q1[:i]
df['Q1'].fillna(0,inplace=True)
df['T1'] = T1[:i]
df['Tsp'] = Tsp1[:i]

# Plot
plt.plot(df['Q1'],'b-',label='$Q_1$ (%)')
plt.plot(df['T1'],'r-',label='$T_1$ $(^oC)$')
plt.plot(df['Tsp'],'k-',label='SP $(^oC)$')
plt.legend()
plt.savefig('PID_train.png');

# %% [markdown]
# ## Feature selection

# %%
# Create new feature: setpoint error
df['err'] = df['Tsp'] - df['T1']

# %%
df.to_csv('PID_train_data.csv',index=False)

# %% [markdown]
# # Load dataset, Scale data, Split into training and test sets

# %%
df = pd.read_csv('PID_train_data.csv')

# %%
X = df[['Tsp','err']].values
y = df[['Q1']].values
# Scale data
s_x = MinMaxScaler()
Xs = s_x.fit_transform(X)

s_y = MinMaxScaler()
ys = s_y.fit_transform(y)

# Each input uses last 'window' number of Tsp and err to predict the next Q1
window = 15
X_lstm = []
y_lstm = []
for i in range(window,len(df)):
    X_lstm.append(Xs[i-window:i])
    y_lstm.append(ys[i])

# Reshape data to format accepted by LSTM
X_lstm, y_lstm = np.array(X_lstm), np.array(y_lstm)

# Split into train and test
Xtrain, Xtest, ytrain, ytest = train_test_split(X_lstm,y_lstm,test_size=0.15,shuffle=False)

# %% [markdown]
# # Model Creation

# %% [markdown]
# ### LSTM Model

# %%
# Keras LSTM model
model_lstm = Sequential()

# First layer specifies input_shape and returns sequences
model_lstm.add(LSTM(units=100, return_sequences=True,
               input_shape=(Xtrain.shape[1],Xtrain.shape[2])))
# Dropout layer to prevent overfitting
model_lstm.add(Dropout(rate=0.1))

# Last layer doesn't return sequences (middle layers should return sequences)
model_lstm.add(LSTM(units=100))
model_lstm.add(Dropout(rate=0.1))

# Dense layer to return prediction
model_lstm.add(Dense(1))

# Compile model; adam optimizer, mse loss
model_lstm.compile(optimizer='adam', loss='mean_squared_error')

es = EarlyStopping(monitor='val_loss',mode='min',verbose=1,patience=25)

result = model_lstm.fit(Xtrain, ytrain, verbose=0, validation_split=0.2,
                   callbacks = [TqdmCallback(verbose=1)],#es
                   batch_size=100,
                   epochs=200)
# Out:
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]

# %%
# Plot loss and save model
plt.semilogy(result.history['loss'],label='loss')
plt.semilogy(result.history['val_loss'],label='val_loss')
plt.legend()
plt.savefig("LSTM_loss_graph_model.png")

# %%
model_lstm.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 15, 100)           41200
#
#  dropout_4 (Dropout)         (None, 15, 100)           0
#
#  lstm_5 (LSTM)               (None, 100)               80400
#
#  dropout_5 (Dropout)         (None, 100)               0
#
#  dense_5 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 121,701
# Trainable params: 121,701
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Deep Learning Model

# %%
# Inisialisasi konstruktor
model_dl = Sequential()
# Tambahkan lapisan masukan
model_dl.add(Dense(2, activation='sigmoid', input_shape=(2,)))
# Tambahkan satu lapisan tersembunyi
model_dl.add(Dense(3, activation='sigmoid'))
# Tambahkan lapisan keluaran
model_dl.add(Dense(3, activation='sigmoid'))

# Data Latih.
X = np.array([
    [1, 1],
    [0.4, 1.2],
    [1.2, 0.1],
    [1, 0.1]
])

# Label untuk Data Latih.
y = np.array([
    [0.25, 4.31, 0.20],
    [0.2, 4.1, 0.1],
    [0.1, 4.0, 0],
    [0.1, 4.0, 0]
])

# Ringkasan model
model_dl.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 2)                 6
#
#  dense_2 (Dense)             (None, 3)                 9
#
#  dense_3 (Dense)             (None, 3)                 12
#
# =================================================================
# Total params: 27
# Trainable params: 27
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_dl.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model_dl.fit(X, y,epochs=100, batch_size=1, verbose=1)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 5ms/step - loss: 0.5355 - accuracy: 0.0000e+00
# Epoch 2/100
# 4/4 [==============================] - 0s 0s/step - loss: 0.5165 - accuracy: 0.0000e+00
# Epoch 3/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4975 - accuracy: 0.0000e+00
# Epoch 4/100
# 4/4 [==============================] - 0s 0s/step - loss: 0.4785 - accuracy: 0.0000e+00
# Epoch 5/100
# 4/4 [==============================] - 0s 0s/step - loss: 0.4594 - accuracy: 0.0000e+00
# Epoch 6/100
# 4/4 [==============================] - 0s 0s/step - loss: 0.4402 - accuracy: 0.0000e+00
# Epoch 7/100
# 4/4 [==============================] - 0s 0s/step - loss: 0.4211 - accuracy: 0.0000e+00
# Epoch 8/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4020 - accuracy: 0.0000e+00
# Epoch 9/100
# 4/4 [==============================] - 0s 0s/step - loss: 0.3828 - accuracy: 0.0000e+00
# Epoch 10/100
# 4/4 [==============================] - 0s 0s/step - loss: 0.3636 - accuracy: 0.0000e+00
# Epoch 11/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3443 - accuracy: 0.0000e+00
# Epoch 12/100
# 4/4 [==============================] - 0s 0s/step - loss: 0.3251 - accuracy: 0.0000e+00
# Epoch 13/100
# 4/4 [==============================] - 0s 0s/step - loss: 0.3058 - accuracy: 0.0000e+00
# Epoch 14/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2864 - accuracy: 0.0000e+00
# Epoch 15/100
# 4/4 [==============================] - 0s 0s/step - loss: 0.2671 - accuracy: 0.0000e+00
# Epoch 16/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2478 - accuracy: 0.0000e+00
# Epoch 17/100
# 4/4 [==============================] - 0s 0s/step - loss: 0.2282 - accuracy: 0.0000e+00
# Epoch 18/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2088 - accuracy: 0.7500
# Epoch 19/100
# 4/4 [==============================] - 0s 0s/step - loss: 0.1893 - accuracy: 1.0000
# Epoch 20/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1698 - accuracy: 1.0000
# Epoch 21/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1501 - accuracy: 1.0000
# Epoch 22/100
# 4/4 [==============================] - 0s 0s/step - loss: 0.1306 - accuracy: 1.0000
# Epoch 23/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1110 - accuracy: 1.0000
# Epoch 24/100
# 4/4 [==============================] - 0s 0s/step - loss: 0.0912 - accuracy: 1.0000
# Epoch 25/100
# 4/4 [==============================] - 0s 0s/step - loss: 0.0716 - accuracy: 1.0000
# Epoch 26/100
# 4/4 [==============================] - 0s 0s/step - loss: 0.0519 - accuracy: 1.0000
# Epoch 27/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0321 - accuracy: 1.0000
# Epoch 28/100
# 4/4 [==============================] - 0s 0s/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 29/100
# 4/4 [==============================] - 0s 0s/step - loss: -0.0075 - accuracy: 1.0000
# Epoch 30/100
# 4/4 [==============================] - 0s 5ms/step - loss: -0.0274 - accuracy: 1.0000
# Epoch 31/100
# 4/4 [==============================] - 0s 0s/step - loss: -0.0474 - accuracy: 1.0000
# Epoch 32/100
# 4/4 [==============================] - 0s 0s/step - loss: -0.0674 - accuracy: 1.0000
# Epoch 33/100
# 4/4 [==============================] - 0s 5ms/step - loss: -0.0873 - accuracy: 1.0000
# Epoch 34/100
# 4/4 [==============================] - 0s 0s/step - loss: -0.1074 - accuracy: 1.0000
# Epoch 35/100
# 4/4 [==============================] - 0s 0s/step - loss: -0.1273 - accuracy: 1.0000
# Epoch 36/100
# 4/4 [==============================] - 0s 5ms/step - loss: -0.1474 - accuracy: 1.0000
# Epoch 37/100
# 4/4 [==============================] - 0s 0s/step - loss: -0.1675 - accuracy: 1.0000
# Epoch 38/100
# 4/4 [==============================] - 0s 0s/step - loss: -0.1876 - accuracy: 1.0000
# Epoch 39/100
# 4/4 [==============================] - 0s 5ms/step - loss: -0.2077 - accuracy: 1.0000
# Epoch 40/100
# 4/4 [==============================] - 0s 0s/step - loss: -0.2279 - accuracy: 1.0000
# Epoch 41/100
# 4/4 [==============================] - 0s 0s/step - loss: -0.2482 - accuracy: 1.0000
# Epoch 42/100
# 4/4 [==============================] - 0s 5ms/step - loss: -0.2685 - accuracy: 1.0000
# Epoch 43/100
# 4/4 [==============================] - 0s 0s/step - loss: -0.2886 - accuracy: 1.0000
# Epoch 44/100
# 4/4 [==============================] - 0s 0s/step - loss: -0.3089 - accuracy: 1.0000
# Epoch 45/100
# 4/4 [==============================] - 0s 5ms/step - loss: -0.3294 - accuracy: 1.0000
# Epoch 46/100
# 4/4 [==============================] - 0s 0s/step - loss: -0.3497 - accuracy: 1.0000
# Epoch 47/100
# 4/4 [==============================] - 0s 0s/step - loss: -0.3699 - accuracy: 1.0000
# Epoch 48/100
# 4/4 [==============================] - 0s 0s/step - loss: -0.3904 - accuracy: 1.0000
# Epoch 49/100
# 4/4 [==============================] - 0s 5ms/step - loss: -0.4108 - accuracy: 1.0000
# Epoch 50/100
# 4/4 [==============================] - 0s 0s/step - loss: -0.4311 - accuracy: 1.0000
# Epoch 51/100
# 4/4 [==============================] - 0s 5ms/step - loss: -0.4515 - accuracy: 1.0000
# Epoch 52/100
# 4/4 [==============================] - 0s 0s/step - loss: -0.4720 - accuracy: 1.0000
# Epoch 53/100
# 4/4 [==============================] - 0s 0s/step - loss: -0.4926 - accuracy: 1.0000
# Epoch 54/100
# 4/4 [==============================] - 0s 5ms/step - loss: -0.5130 - accuracy: 1.0000
# Epoch 55/100
# 4/4 [==============================] - 0s 0s/step - loss: -0.5336 - accuracy: 1.0000
# Epoch 56/100
# 4/4 [==============================] - 0s 0s/step - loss: -0.5541 - accuracy: 1.0000
# Epoch 57/100
# 4/4 [==============================] - 0s 5ms/step - loss: -0.5745 - accuracy: 1.0000
# Epoch 58/100
# 4/4 [==============================] - 0s 0s/step - loss: -0.5950 - accuracy: 1.0000
# Epoch 59/100
# 4/4 [==============================] - 0s 0s/step - loss: -0.6156 - accuracy: 1.0000
# Epoch 60/100
# 4/4 [==============================] - 0s 5ms/step - loss: -0.6362 - accuracy: 1.0000
# Epoch 61/100
# 4/4 [==============================] - 0s 0s/step - loss: -0.6566 - accuracy: 1.0000
# Epoch 62/100
# 4/4 [==============================] - 0s 5ms/step - loss: -0.6773 - accuracy: 1.0000
# Epoch 63/100
# 4/4 [==============================] - 0s 0s/step - loss: -0.6979 - accuracy: 1.0000
# Epoch 64/100
# 4/4 [==============================] - 0s 0s/step - loss: -0.7184 - accuracy: 1.0000
# Epoch 65/100
# 4/4 [==============================] - 0s 5ms/step - loss: -0.7390 - accuracy: 1.0000
# Epoch 66/100
# 4/4 [==============================] - 0s 0s/step - loss: -0.7597 - accuracy: 1.0000
# Epoch 67/100
# 4/4 [==============================] - 0s 0s/step - loss: -0.7801 - accuracy: 1.0000
# Epoch 68/100
# 4/4 [==============================] - 0s 5ms/step - loss: -0.8009 - accuracy: 1.0000
# Epoch 69/100
# 4/4 [==============================] - 0s 0s/step - loss: -0.8215 - accuracy: 1.0000
# Epoch 70/100
# 4/4 [==============================] - 0s 0s/step - loss: -0.8419 - accuracy: 1.0000
# Epoch 71/100
# 4/4 [==============================] - 0s 0s/step - loss: -0.8625 - accuracy: 1.0000
# Epoch 72/100
# 4/4 [==============================] - 0s 0s/step - loss: -0.8830 - accuracy: 1.0000
# Epoch 73/100
# 4/4 [==============================] - 0s 5ms/step - loss: -0.9037 - accuracy: 1.0000
# Epoch 74/100
# 4/4 [==============================] - 0s 0s/step - loss: -0.9243 - accuracy: 1.0000
# Epoch 75/100
# 4/4 [==============================] - 0s 5ms/step - loss: -0.9449 - accuracy: 1.0000
# Epoch 76/100
# 4/4 [==============================] - 0s 0s/step - loss: -0.9653 - accuracy: 1.0000
# Epoch 77/100
# 4/4 [==============================] - 0s 0s/step - loss: -0.9860 - accuracy: 1.0000
# Epoch 78/100
# 4/4 [==============================] - 0s 0s/step - loss: -1.0065 - accuracy: 1.0000
# Epoch 79/100
# 4/4 [==============================] - 0s 0s/step - loss: -1.0269 - accuracy: 1.0000
# Epoch 80/100
# 4/4 [==============================] - 0s 5ms/step - loss: -1.0475 - accuracy: 1.0000
# Epoch 81/100
# 4/4 [==============================] - 0s 0s/step - loss: -1.0680 - accuracy: 1.0000
# Epoch 82/100
# 4/4 [==============================] - 0s 5ms/step - loss: -1.0885 - accuracy: 1.0000
# Epoch 83/100
# 4/4 [==============================] - 0s 0s/step - loss: -1.1090 - accuracy: 1.0000
# Epoch 84/100
# 4/4 [==============================] - 0s 0s/step - loss: -1.1294 - accuracy: 1.0000
# Epoch 85/100
# 4/4 [==============================] - 0s 5ms/step - loss: -1.1498 - accuracy: 1.0000
# Epoch 86/100
# 4/4 [==============================] - 0s 0s/step - loss: -1.1704 - accuracy: 1.0000
# Epoch 87/100
# 4/4 [==============================] - 0s 0s/step - loss: -1.1907 - accuracy: 1.0000
# Epoch 88/100
# 4/4 [==============================] - 0s 5ms/step - loss: -1.2111 - accuracy: 1.0000
# Epoch 89/100
# 4/4 [==============================] - 0s 0s/step - loss: -1.2313 - accuracy: 1.0000
# Epoch 90/100
# 4/4 [==============================] - 0s 5ms/step - loss: -1.2518 - accuracy: 1.0000
# Epoch 91/100
# 4/4 [==============================] - 0s 0s/step - loss: -1.2721 - accuracy: 1.0000
# Epoch 92/100
# 4/4 [==============================] - 0s 0s/step - loss: -1.2925 - accuracy: 1.0000
# Epoch 93/100
# 4/4 [==============================] - 0s 5ms/step - loss: -1.3127 - accuracy: 1.0000
# Epoch 94/100
# 4/4 [==============================] - 0s 0s/step - loss: -1.3330 - accuracy: 1.0000
# Epoch 95/100
# 4/4 [==============================] - 0s 0s/step - loss: -1.3531 - accuracy: 1.0000
# Epoch 96/100
# 4/4 [==============================] - 0s 5ms/step - loss: -1.3733 - accuracy: 1.0000
# Epoch 97/100
# 4/4 [==============================] - 0s 0s/step - loss: -1.3935 - accuracy: 1.0000
# Epoch 98/100
# 4/4 [==============================] - 0s 5ms/step - loss: -1.4138 - accuracy: 1.0000
# Epoch 99/100
# 4/4 [==============================] - 0s 0s/step - loss: -1.4338 - accuracy: 1.0000
# Epoch 100/100
# 4/4 [==============================] - 0s 0s/step - loss: -1.4540 - accuracy: 1.0000

# %% [markdown]
# ### PID Deep Learning Controller

# %%
def pid_dl(sp,pv,pv_last,ierr,dt):

    # calculate the error
    error = sp-pv
    d_error = sp-pv_last
    delta_error = (error - d_error)

    outDL = model_dl.predict(np.array([[error,delta_error]]))

    Kc = outDL[0,0]
    tauI = outDL[0,1]
    tauD = outDL[0,2]

    # Parameters in terms of PID coefficients
    KP = Kc
    KI = Kc/tauI
    KD = Kc*tauD
    # ubias for controller (initial heater)
    op0 = 0
    # upper and lower bounds on heater level
    ophi = 100
    oplo = 0

    # calculate the integral error
    ierr = ierr + KI * error * dt
    # calculate the measurement derivative
    dpv = (pv - pv_last) / dt
    # calculate the PID output
    P = KP * error
    I = ierr
    D = -KD * dpv
    op = op0 + P + I + D
    # implement anti-reset windup
    if op < oplo or op > ophi:
        I = I - KI * error * dt
        # clip output
        op = max(oplo,min(ophi,op))
    # return the controller output and PID terms
    return [op,P,I,D]

# %% [markdown]
# ### LSTM PID Controller

# %%
def lstm(T1_m, Tsp_m):
    # Calculate error (necessary feature for LSTM input)
    err = Tsp_m - T1_m
    # Format data for LSTM input
    X = np.vstack((Tsp_m,err)).T
    Xs = s_x.transform(X)
    Xs = np.reshape(Xs, (1, Xs.shape[0], Xs.shape[1]))
    # Predict Q for controller and unscale
    Q1c_s = model_lstm.predict(Xs)
    Q1c = s_y.inverse_transform(Q1c_s)[0][0]
    # Ensure Q1c is between 0 and 100
    Q1c = np.clip(Q1c,0.0,100.0)
    return Q1c

# %% [markdown]
# ### Generate SP data for test

# %%
# Run time in minutes
run_time = 6.0

# Number of cycles
loops = int(60.0 * run_time)

# Arrays for storing data
T1 = np.zeros(loops)  # Measured T (degC)
Qpid = np.zeros(loops)  # Heater values for PID controller
Qlstm = np.zeros(loops)  # Heater values for LSTM controller
QDL = np.zeros(loops)  # Heater values for DL controller
tm = np.zeros(loops)  # Time
Tsp = np.zeros(loops)
# Set Tsp to 40°C for 5 minutes
Tsp[:300] = 40.0

# Leave the rest as the initial value (room temperature)
Tsp[300:] = Tsp[0]

plt.plot(Tsp)
plt.show()

# %%
def step_info(resp, t, set_point):
    """
    Calculates overshoot, settling time, and rising time of a step response.

    Parameters:
    - resp: numpy array, step response values
    - t: numpy array, time vector corresponding to the step response
    - set_point: float, the desired set point of the system
    """

    # Calculate overshoot
    max_resp = np.max(resp)
    overshoot = ((max_resp - set_point) / set_point) * 100

    # Calculate settling time
    within_range = np.where((resp >= set_point * 0.98) & (resp <= set_point * 1.02))[0]
    if len(within_range) > 0:
        settling_time = t[within_range[-1]] - t[within_range[0]]
    else:
        settling_time = np.inf

    # Calculate rising time
    first_crossing = np.where(resp >= set_point * 0.1)[0][0]
    last_crossing = np.where(resp >= set_point * 0.9)[0][0]
    rising_time = t[last_crossing] - t[first_crossing]

    # Print the results
    print("Overshoot: {:.2f}%".format(overshoot))
    print("Settling Time: {:.2f} seconds".format(settling_time))
    print("Rising Time: {:.2f} seconds".format(rising_time))
    return overshoot, settling_time, rising_time

# %% [markdown]
# # Testing With itclab

# %%
a = itclab.iTCLab()
a.LED(0)
print(a.T1)
a.close()
# Out:
# Opening connection
# iTCLab connected via Arduino on port COM5
# 30.03
# Arduino disconnected successfully
# True

# %%
a = itclab.iTCLab()
print('LED On')
a.LED(100)

run_times = 8
loops = int(60.0*run_time)
tm = np.zeros(loops)
T1 = np.zeros(loops)
Tsp = np.zeros(loops)
Q1 = np.zeros(loops)
# Set point to 40 all the time
Tsp[:] = 40

start_time = time.time()
prev_time = start_time
ierr = 0.0
try:
    for i in range(1,loops):
        # Sleep time
        sleep_max = 1.0
        sleep = sleep_max - (time.time() - prev_time)
        if sleep>=0.01:
            time.sleep(sleep-0.01)
        else:
            time.sleep(0.01)

        # Record time and change in time
        t = time.time()
        dt = t - prev_time
        prev_time = t
        tm[i] = t - start_time

        # Read temperatures in C
        T1[i] = a.T1

        [Q1[i],P,ierr,D] = pid(Tsp[i],T1[i],T1[i-1],ierr,dt)

        a.Q1(Q1[i])
        a.Q2(0.0)
        print(('{:6.1f} {:6.2f} {:6.2f} ' + \
               '{:6.2f} ').format( \
            tm[i],Tsp[i],T1[i], \
            Q1[i]))

except KeyboardInterrupt:
    # Disconnect from Arduino
    a.Q1(0)
    a.Q2(0)
    print('Shutting down')
    a.close()


# Make sure serial connection still closes when there's an error
except:
    # Disconnect from Arduino
    a.Q1(0)
    a.Q2(0)
    print('Error: Shutting down')
    a.close()

    raise

a.Q1(0.0)
a.Q2(0.0)
a.close()
# Out:
# Opening connection
# iTCLab connected via Arduino on port COM5
# LED On
#    1.0  40.00  30.14  59.94
#    2.0  40.00  30.17  60.55
#    3.0  40.00  30.09  61.82
#    4.0  40.00  30.12  62.43
#    5.0  40.00  30.05  63.64
#    6.0  40.00  30.14  63.89
#    7.0  40.00  30.22  64.19
#    8.0  40.00  30.20  65.09
#    9.0  40.00  30.19  65.93
#   10.0  40.00  30.14  67.02
#   11.0  40.00  30.19  67.50
#   12.0  40.00  30.27  67.79
#   13.0  40.00  30.37  67.96
#   13.9  40.00  30.34  68.91
#   14.9  40.00  30.43  69.13
#   15.9  40.00  30.58  68.98
#   16.9  40.00  30.61  69.54
#   17.9  40.00  30.75  69.44
#   18.9  40.00  30.82  69.75
#   19.9  40.00  30.91  69.94
#   20.9  40.00  31.00  70.12
#   21.9  40.00  31.09  70.28
#   22.9  40.00  31.14  70.69
#   23.9  40.00  31.26  70.66
#   24.9  40.00  31.26  71.36
#   25.9  40.00  31.36  71.45
#   26.9  40.00  31.40  71.90
#   27.9  40.00  31.43  72.40
#   28.9  40.00  31.46  72.90
#   29.9  40.00  31.62  72.61
#   30.9  40.00  31.57  73.58
#   31.9  40.00  31.68  73.58
#   32.9  40.00  31.74  73.88
#   33.9  40.00  31.88  73.69
plt.text(0.2, -0.2, 'Overshoot: {:.2f} %'.format(overshoot), ha='right', va='center', transform=plt.gca().transAxes, fontsize=12)
# add set point label
plt.text(0.2, -0.3, 'Set Point: {:.2f} °C'.format(Tsp[0]), ha='right', va='center', transform=plt.gca().transAxes, fontsize=12)


# Add rising time annotation
plt.axvline(x=rise_time, color='c', linestyle='--', label='Rising Time: {:.2f} seconds'.format(rise_time))
# add settling time annotation
plt.axvline(x=settling_time, color='m', linestyle='--', label='Settling Time: {:.2f} seconds'.format(settling_time))

plt.legend(fontsize=14, bbox_to_anchor=(1.04, 0.5), loc="center left", borderaxespad=0)
plt.ylim((0,100))
plt.xlabel('Time (s)',size=14)
plt.xticks(size=12)
plt.yticks(size=12)
plt.grid()
plt.show()

# %%
a.close()
# Out:
# Arduino disconnected successfully
# True

# %%
# stop for 3 minutes code
for i in range(1,3):
    print(i)
    time.sleep(60)
# Out:
# 1
# 2
# 3
# 4

# %%
a = itclab.iTCLab()
a.LED(0)
print(a.T1)
a.close()
# Out:
# Opening connection
# iTCLab connected via Arduino on port COM5
# 30.29
# Arduino disconnected successfully
# True

# %%
a = itclab.iTCLab()
print('LED On')
a.LED(100)
run_times = 8
loops = int(60.0*run_time)
tm = np.zeros(loops)
T1 = np.zeros(loops)
Tsp = np.zeros(loops)
Q1 = np.zeros(loops)
# Set point to 40 all the time
Tsp[:] = 40

start_time = time.time()
prev_time = start_time
ierr = 0.0
try:
    for i in range(1,loops):
        # Sleep time
        sleep_max = 1.0
        sleep = sleep_max - (time.time() - prev_time)
        if sleep>=0.01:
            time.sleep(sleep-0.01)
        else:
            time.sleep(0.01)

        # Record time and change in time
        t = time.time()
        dt = t - prev_time
        prev_time = t
        tm[i] = t - start_time

        # Read temperatures in C
        T1[i] = a.T1

        [Q1[i],P,ierr,D] = pid_dl(Tsp[i],T1[i],T1[i-1],ierr,dt)

        a.Q1(Q1[i])
        a.Q2(0.0)
        print(('{:6.1f} {:6.2f} {:6.2f} ' + \
               '{:6.2f} ').format( \
            tm[i],Tsp[i],T1[i], \
            Q1[i]))

except KeyboardInterrupt:
    # Disconnect from Arduino
    a.Q1(0)
    a.Q2(0)
    print('Shutting down')
    a.close()


# Make sure serial connection still closes when there's an error
except:
    # Disconnect from Arduino
    a.Q1(0)
    a.Q2(0)
    print('Error: Shutting down')
    a.close()

    raise

a.close()
# Out:
# Opening connection
# iTCLab connected via Arduino on port COM5
# LED On
# 1/1 [==============================] - 0s 16ms/step
#    1.0  40.00  30.33   1.42
# 1/1 [==============================] - 0s 16ms/step
#    2.0  40.00  30.24   5.85
# 1/1 [==============================] - 0s 16ms/step
#    3.0  40.00  30.17   7.94
# 1/1 [==============================] - 0s 16ms/step
#    4.0  40.00  30.28   9.96
# 1/1 [==============================] - 0s 16ms/step
#    5.0  40.00  30.27  12.01
# 1/1 [==============================] - 0s 16ms/step
#    6.0  40.00  30.18  14.08
# 1/1 [==============================] - 0s 31ms/step
#    7.0  40.00  30.27  16.09
# 1/1 [==============================] - 0s 16ms/step
#    8.0  40.00  30.15  18.21
#   46.9  40.00  34.13  86.05
# 1/1 [==============================] - 0s 31ms/step
#   47.9  40.00  34.35  87.21
# 1/1 [==============================] - 0s 16ms/step
#   48.9  40.00  34.58  88.32
# 1/1 [==============================] - 0s 16ms/step
#   49.9  40.00  34.67  89.46
# 1/1 [==============================] - 0s 16ms/step
#   50.9  40.00  34.83  90.52
# 1/1 [==============================] - 0s 16ms/step
#   51.9  40.00  35.11  91.51
# 1/1 [==============================] - 0s 16ms/step
#   52.9  40.00  35.18  92.55
# 1/1 [==============================] - 0s 16ms/step
#   53.9  40.00  35.23  93.56
# 1/1 [==============================] - 0s 13ms/step
#   54.9  40.00  35.33  94.53
# 1/1 [==============================] - 0s 16ms/step
#   55.9  40.00  35.43  95.48
# 1/1 [==============================] - 0s 16ms/step
#   56.8  40.00  35.59  96.39
# 1/1 [==============================] - 0s 16ms/step
#   57.9  40.00  35.67  97.31
# 1/1 [==============================] - 0s 16ms/step
#   58.9  40.00  35.72  98.23
# 1/1 [==============================] - 0s 16ms/step
#   59.9  40.00  35.75  99.14
# 1/1 [==============================] - 0s 16ms/step
#   60.9  40.00  35.74 100.00
# 1/1 [==============================] - 0s 17ms/step
#   61.9  40.00  35.80 100.00
# 1/1 [==============================] - 0s 16ms/step
#   62.9  40.00  35.83 100.00
# 1/1 [==============================] - 0s 16ms/step
#   63.8  40.00  35.94  99.97
# 1/1 [==============================] - 0s 16ms/step
#   64.8  40.00  36.18 100.00
# 1/1 [==============================] - 0s 16ms/step
#   65.8  40.00  36.50 100.00
# 1/1 [==============================] - 0s 16ms/step
#   66.8  40.00  36.60 100.00
# 1/1 [==============================] - 0s 16ms/step
#   67.8  40.00  36.76 100.00
# 1/1 [==============================] - 0s 16ms/step
#   68.8  40.00  36.79 100.00
# 1/1 [==============================] - 0s 16ms/step
#   69.8  40.00  36.93 100.00
# 1/1 [==============================] - 0s 16ms/step
#   70.8  40.00  37.12 100.00
# 1/1 [==============================] - 0s 16ms/step
#   71.8  40.00  37.33 100.00
# 1/1 [==============================] - 0s 16ms/step
#   72.8  40.00  37.45 100.00
# 1/1 [==============================] - 0s 16ms/step
#   73.8  40.00  37.57 100.00
# 1/1 [==============================] - 0s 16ms/step
#   74.8  40.00  37.80 100.00
# 1/1 [==============================] - 0s 25ms/step
#   75.8  40.00  37.97 100.00
# 1/1 [==============================] - 0s 16ms/step
#   76.8  40.00  38.24  99.91
# 1/1 [==============================] - 0s 31ms/step
#   77.8  40.00  38.38 100.00
# 1/1 [==============================] - 0s 16ms/step
#   78.8  40.00  38.62 100.00
# 1/1 [==============================] - 0s 16ms/step
#   79.8  40.00  38.69 100.00
# 1/1 [==============================] - 0s 31ms/step
#   80.8  40.00  38.77 100.00
# 1/1 [==============================] - 0s 16ms/step
#   81.8  40.00  38.93 100.00
# 1/1 [==============================] - 0s 16ms/step
#   82.8  40.00  39.17  99.93
# 1/1 [==============================] - 0s 16ms/step
#   83.8  40.00  39.07 100.00
# 1/1 [==============================] - 0s 16ms/step
#   84.8  40.00  39.28 100.00
# 1/1 [==============================] - 0s 16ms/step
#   85.8  40.00  39.46 100.00
# 1/1 [==============================] - 0s 16ms/step
#   86.8  40.00  39.63 100.00
# 1/1 [==============================] - 0s 16ms/step
#   87.8  40.00  39.66 100.00
# 1/1 [==============================] - 0s 16ms/step
#   88.8  40.00  39.75 100.00
# 1/1 [==============================] - 0s 16ms/step
#   89.8  40.00  39.86  99.96
# 1/1 [==============================] - 0s 16ms/step
#   90.8  40.00  40.09  99.88
# 1/1 [==============================] - 0s 16ms/step
#   91.8  40.00  40.11  99.87
# 1/1 [==============================] - 0s 16ms/step
#   92.8  40.00  40.33  99.74
# 1/1 [==============================] - 0s 16ms/step
#   93.8  40.00  40.49  99.60
# 1/1 [==============================] - 0s 16ms/step
#   94.8  40.00  40.61  99.44
# 1/1 [==============================] - 0s 16ms/step
#   95.8  40.00  40.90  99.17
# 1/1 [==============================] - 0s 16ms/step
#   96.8  40.00  40.92  98.97
# 1/1 [==============================] - 0s 16ms/step
#   97.8  40.00  40.98  98.74
# 1/1 [==============================] - 0s 16ms/step
#   98.8  40.00  41.23  98.39
# 1/1 [==============================] - 0s 16ms/step
#   99.8  40.00  41.39  98.04
# 1/1 [==============================] - 0s 12ms/step
#  100.8  40.00  41.58  97.64
# 1/1 [==============================] - 0s 16ms/step
#  101.8  40.00  41.79  97.18
# 1/1 [==============================] - 0s 16ms/step
#  102.8  40.00  41.88  96.74
# 1/1 [==============================] - 0s 16ms/step
#  103.8  40.00  41.91  96.30
# 1/1 [==============================] - 0s 16ms/step
#  104.8  40.00  42.08  95.77
# 1/1 [==============================] - 0s 16ms/step
#  105.8  40.00  42.12  95.27
# 1/1 [==============================] - 0s 16ms/step
#  106.8  40.00  42.18  94.75
# 1/1 [==============================] - 0s 16ms/step
#  107.8  40.00  42.01  94.33
# 1/1 [==============================] - 0s 16ms/step
#  108.8  40.00  41.84  93.94
# 1/1 [==============================] - 0s 16ms/step
#  109.8  40.00  41.95  93.44
# 1/1 [==============================] - 0s 16ms/step
#  110.8  40.00  42.13  92.90
# 1/1 [==============================] - 0s 16ms/step
#  111.8  40.00  42.26  92.35
# 1/1 [==============================] - 0s 16ms/step
#  112.8  40.00  42.31  91.80
# 1/1 [==============================] - 0s 16ms/step
#  113.8  40.00  42.50  91.16
# 1/1 [==============================] - 0s 16ms/step
#  114.8  40.00  42.74  90.47
# 1/1 [==============================] - 0s 16ms/step
#  115.8  40.00  42.82  89.80
# 1/1 [==============================] - 0s 16ms/step
#  116.8  40.00  42.70  89.20
# 1/1 [==============================] - 0s 16ms/step
#  117.7  40.00  42.78  88.52
# 1/1 [==============================] - 0s 16ms/step
#  118.7  40.00  42.66  87.93
# 1/1 [==============================] - 0s 16ms/step
#  119.7  40.00  42.68  87.28
# 1/1 [==============================] - 0s 16ms/step
#  120.7  40.00  42.86  86.55
# 1/1 [==============================] - 0s 16ms/step
#  121.7  40.00  42.89  85.87
# 1/1 [==============================] - 0s 16ms/step
#  122.7  40.00  43.05  85.11
# 1/1 [==============================] - 0s 16ms/step
#  123.7  40.00  43.20  84.32
# 1/1 [==============================] - 0s 16ms/step
#  124.7  40.00  43.39  83.46
# 1/1 [==============================] - 0s 16ms/step
#  125.7  40.00  43.71  82.49
# 1/1 [==============================] - 0s 16ms/step
#  126.7  40.00  43.82  81.56
# 1/1 [==============================] - 0s 16ms/step
#  127.7  40.00  44.09  80.50
# 1/1 [==============================] - 0s 31ms/step
#  128.7  40.00  44.26  79.44
# 1/1 [==============================] - 0s 16ms/step
#  129.7  40.00  44.38  78.34
# 1/1 [==============================] - 0s 16ms/step
#  130.7  40.00  44.42  77.27
# 1/1 [==============================] - 0s 16ms/step
#  131.7  40.00  44.39  76.21
# 1/1 [==============================] - 0s 16ms/step
#  132.7  40.00  44.34  75.17
# 1/1 [==============================] - 0s 16ms/step
#  133.7  40.00  44.23  74.17
# 1/1 [==============================] - 0s 16ms/step
#  134.7  40.00  44.17  73.17
# 1/1 [==============================] - 0s 16ms/step
#  135.7  40.00  44.43  72.00
# 1/1 [==============================] - 0s 16ms/step
#  136.7  40.00  44.59  70.86
# 1/1 [==============================] - 0s 16ms/step
#  137.7  40.00  44.73  69.67
# 1/1 [==============================] - 0s 31ms/step
#  138.7  40.00  44.52  68.62
# 1/1 [==============================] - 0s 16ms/step
#  139.7  40.00  44.70  67.40
# 1/1 [==============================] - 0s 25ms/step
#  140.7  40.00  44.91  66.15
# 1/1 [==============================] - 0s 16ms/step
#  141.7  40.00  44.99  64.90
# 1/1 [==============================] - 0s 31ms/step
#  142.7  40.00  44.62  63.87
# 1/1 [==============================] - 0s 16ms/step
#  143.7  40.00  44.60  62.72
# 1/1 [==============================] - 0s 16ms/step
#  144.7  40.00  44.17  61.83
# 1/1 [==============================] - 0s 16ms/step
#  145.7  40.00  44.07  60.84
# 1/1 [==============================] - 0s 16ms/step
#  146.7  40.00  44.02  59.88
# 1/1 [==============================] - 0s 16ms/step
#  147.7  40.00  44.08  58.87
# 1/1 [==============================] - 0s 16ms/step
#  148.7  40.00  44.11  57.87
# 1/1 [==============================] - 0s 16ms/step
#  149.7  40.00  44.21  56.82
# 1/1 [==============================] - 0s 16ms/step
#  150.7  40.00  44.33  55.74
# 1/1 [==============================] - 0s 16ms/step
#  151.7  40.00  44.34  54.70
# 1/1 [==============================] - 0s 16ms/step
#  152.6  40.00  44.32  53.65
# 1/1 [==============================] - 0s 16ms/step
#  153.6  40.00  44.40  52.55
# 1/1 [==============================] - 0s 16ms/step
#  154.6  40.00  44.79  51.27
# 1/1 [==============================] - 0s 16ms/step
#  155.6  40.00  44.99  50.00
# 1/1 [==============================] - 0s 16ms/step
#  156.6  40.00  45.27  48.63
# 1/1 [==============================] - 0s 16ms/step
#  157.6  40.00  45.41  47.25
# 1/1 [==============================] - 0s 16ms/step
#  158.7  40.00  45.61  45.79
# 1/1 [==============================] - 0s 31ms/step
#  159.7  40.00  45.48  44.47
# 1/1 [==============================] - 0s 16ms/step
#  160.7  40.00  45.43  43.12
# 1/1 [==============================] - 0s 16ms/step
#  161.7  40.00  45.31  41.82
# 1/1 [==============================] - 0s 16ms/step
#  162.7  40.00  45.27  40.50
# 1/1 [==============================] - 0s 16ms/step
#  163.7  40.00  45.16  39.25
# 1/1 [==============================] - 0s 16ms/step
#  164.7  40.00  45.04  38.02
# 1/1 [==============================] - 0s 31ms/step
#  165.7  40.00  45.21  36.67
# 1/1 [==============================] - 0s 16ms/step
#  166.7  40.00  45.36  35.31
# 1/1 [==============================] - 0s 16ms/step
#  167.7  40.00  45.28  34.02
# 1/1 [==============================] - 0s 16ms/step
#  168.7  40.00  44.92  32.90
# 1/1 [==============================] - 0s 25ms/step
#  169.7  40.00  44.80  31.73
# 1/1 [==============================] - 0s 16ms/step
#  170.7  40.00  44.54  30.67
# 1/1 [==============================] - 0s 16ms/step
#  171.6  40.00  44.50  29.57
# 1/1 [==============================] - 0s 16ms/step
#  172.6  40.00  44.59  28.42
# 1/1 [==============================] - 0s 16ms/step
#  173.6  40.00  44.81  27.18
# 1/1 [==============================] - 0s 16ms/step
#  174.6  40.00  44.96  25.93
# 1/1 [==============================] - 0s 16ms/step
#  175.6  40.00  45.26  24.56
# 1/1 [==============================] - 0s 16ms/step
#  176.6  40.00  45.41  23.19
# 1/1 [==============================] - 0s 16ms/step
#  177.6  40.00  45.59  21.74
# 1/1 [==============================] - 0s 16ms/step
#  178.6  40.00  45.80  20.23
# 1/1 [==============================] - 0s 16ms/step
#  179.6  40.00  45.81  18.80
# 1/1 [==============================] - 0s 16ms/step
#  180.6  40.00  45.83  17.33
# 1/1 [==============================] - 0s 16ms/step
#  181.6  40.00  45.72  15.92
# 1/1 [==============================] - 0s 16ms/step
#  182.6  40.00  45.68  14.51
# 1/1 [==============================] - 0s 16ms/step
#  183.6  40.00  45.88  12.97
# 1/1 [==============================] - 0s 16ms/step
#  184.6  40.00  45.95  11.47
# 1/1 [==============================] - 0s 16ms/step
#  185.6  40.00  46.10   9.89
# 1/1 [==============================] - 0s 31ms/step
#  186.6  40.00  46.43   8.18
# 1/1 [==============================] - 0s 16ms/step
#  187.6  40.00  46.31   6.63
# 1/1 [==============================] - 0s 16ms/step
#  188.6  40.00  46.25   5.06
# 1/1 [==============================] - 0s 16ms/step
#  189.6  40.00  46.49   3.34
# 1/1 [==============================] - 0s 16ms/step
#  190.6  40.00  46.56   1.67
# 1/1 [==============================] - 0s 16ms/step
#  191.6  40.00  46.61   0.00
# 1/1 [==============================] - 0s 16ms/step
#  192.6  40.00  46.93   0.00
# 1/1 [==============================] - 0s 16ms/step
#  193.6  40.00  47.17   0.00
# 1/1 [==============================] - 0s 16ms/step
#  194.6  40.00  46.99   0.00
# 1/1 [==============================] - 0s 16ms/step
#  195.6  40.00  46.92   0.00
# 1/1 [==============================] - 0s 16ms/step
#  196.6  40.00  46.73   0.00
# 1/1 [==============================] - 0s 16ms/step
#  197.6  40.00  46.95   0.00
# 1/1 [==============================] - 0s 16ms/step
#  198.6  40.00  46.98   0.00
# 1/1 [==============================] - 0s 16ms/step
#  199.6  40.00  47.23   0.00
# 1/1 [==============================] - 0s 16ms/step
#  200.6  40.00  47.10   0.00
# 1/1 [==============================] - 0s 16ms/step
#  201.5  40.00  47.17   0.00
# 1/1 [==============================] - 0s 16ms/step
#  202.5  40.00  47.10   0.00
# 1/1 [==============================] - 0s 16ms/step
#  203.5  40.00  47.30   0.00
# 1/1 [==============================] - 0s 16ms/step
#  204.5  40.00  47.32   0.00
# 1/1 [==============================] - 0s 16ms/step
#  205.5  40.00  47.41   0.00
# 1/1 [==============================] - 0s 16ms/step
#  206.5  40.00  47.24   0.00
# 1/1 [==============================] - 0s 16ms/step
#  207.5  40.00  46.81   0.00
# 1/1 [==============================] - 0s 16ms/step
#  208.5  40.00  46.67   0.00
# 1/1 [==============================] - 0s 16ms/step
#  209.5  40.00  46.47   0.06
# 1/1 [==============================] - 0s 16ms/step
#  210.5  40.00  46.55   0.00
# 1/1 [==============================] - 0s 31ms/step
#  211.5  40.00  46.66   0.00
# 1/1 [==============================] - 0s 16ms/step
#  212.5  40.00  46.78   0.00
# 1/1 [==============================] - 0s 16ms/step
#  213.5  40.00  46.78   0.00
# 1/1 [==============================] - 0s 16ms/step
#  214.5  40.00  46.60   0.00
# 1/1 [==============================] - 0s 23ms/step
#  215.5  40.00  46.69   0.00
# 1/1 [==============================] - 0s 16ms/step
#  216.5  40.00  46.67   0.00
# 1/1 [==============================] - 0s 16ms/step
#  217.5  40.00  46.72   0.00
# 1/1 [==============================] - 0s 16ms/step
#  218.5  40.00  46.78   0.00
# 1/1 [==============================] - 0s 31ms/step
#  219.5  40.00  46.77   0.00
# 1/1 [==============================] - 0s 16ms/step
#  220.5  40.00  46.67   0.00
# 1/1 [==============================] - 0s 16ms/step
#  221.5  40.00  46.66   0.00
# 1/1 [==============================] - 0s 16ms/step
#  222.5  40.00  46.16   0.00
# 1/1 [==============================] - 0s 16ms/step
#  223.5  40.00  45.52   0.00
# 1/1 [==============================] - 0s 16ms/step
#  224.5  40.00  45.13   0.00
# 1/1 [==============================] - 0s 16ms/step
#  225.5  40.00  44.69   0.00
# 1/1 [==============================] - 0s 16ms/step
#  226.5  40.00  44.11   0.00
# 1/1 [==============================] - 0s 16ms/step
#  227.5  40.00  43.90   0.00
# 1/1 [==============================] - 0s 16ms/step
#  228.5  40.00  44.00   0.00
# 1/1 [==============================] - 0s 16ms/step
#  229.5  40.00  44.11   0.00
# 1/1 [==============================] - 0s 16ms/step
#  230.5  40.00  43.95   0.00
# 1/1 [==============================] - 0s 16ms/step
#  231.5  40.00  43.55   0.00
# 1/1 [==============================] - 0s 16ms/step
#  232.5  40.00  43.26   0.01
# 1/1 [==============================] - 0s 16ms/step
#  233.5  40.00  43.33   0.00
# 1/1 [==============================] - 0s 16ms/step
#  234.5  40.00  43.28   0.00
# 1/1 [==============================] - 0s 16ms/step
#  235.5  40.00  43.34   0.00
# 1/1 [==============================] - 0s 16ms/step
#  236.5  40.00  43.17   0.00
# 1/1 [==============================] - 0s 16ms/step
#  237.5  40.00  43.01   0.00
# 1/1 [==============================] - 0s 16ms/step
#  238.4  40.00  42.88   0.00
# 1/1 [==============================] - 0s 16ms/step
#  239.4  40.00  42.77   0.00
# 1/1 [==============================] - 0s 31ms/step
#  240.4  40.00  42.56   0.00
# 1/1 [==============================] - 0s 16ms/step
#  241.4  40.00  42.33   0.00
# 1/1 [==============================] - 0s 16ms/step
#  242.4  40.00  42.23   0.00
# 1/1 [==============================] - 0s 16ms/step
#  243.4  40.00  42.10   0.00
# 1/1 [==============================] - 0s 16ms/step
#  244.4  40.00  42.01   0.00
# 1/1 [==============================] - 0s 16ms/step
#  245.4  40.00  41.88   0.00
# 1/1 [==============================] - 0s 16ms/step
#  246.4  40.00  41.81   0.00
# 1/1 [==============================] - 0s 16ms/step
#  247.4  40.00  41.69   0.00
# 1/1 [==============================] - 0s 25ms/step
#  248.4  40.00  41.63   0.00
# 1/1 [==============================] - 0s 16ms/step
#  249.4  40.00  41.65   0.00
# 1/1 [==============================] - 0s 16ms/step
#  250.4  40.00  41.60   0.00
# 1/1 [==============================] - 0s 16ms/step
#  251.4  40.00  41.53   0.00
# 1/1 [==============================] - 0s 16ms/step
#  252.4  40.00  41.29   0.11
# 1/1 [==============================] - 0s 16ms/step
#  253.4  40.00  41.20   0.00
# 1/1 [==============================] - 0s 16ms/step
#  254.4  40.00  41.15   0.00
# 1/1 [==============================] - 0s 16ms/step
#  255.4  40.00  40.98   0.00
# 1/1 [==============================] - 0s 16ms/step
#  256.4  40.00  40.80   0.02
# 1/1 [==============================] - 0s 16ms/step
#  257.4  40.00  40.65   0.00
# 1/1 [==============================] - 0s 16ms/step
#  258.3  40.00  40.48   0.00
# 1/1 [==============================] - 0s 16ms/step
#  259.3  40.00  40.35   0.03
# 1/1 [==============================] - 0s 16ms/step
#  260.3  40.00  40.22   0.01
# 1/1 [==============================] - 0s 16ms/step
#  261.3  40.00  40.09   0.01
# 1/1 [==============================] - 0s 16ms/step
#  262.3  40.00  39.86   0.09
# 1/1 [==============================] - 0s 16ms/step
#  263.3  40.00  39.76   0.16
# 1/1 [==============================] - 0s 16ms/step
#  264.3  40.00  39.53   0.32
# 1/1 [==============================] - 0s 16ms/step
#  265.3  40.00  39.42   0.46
# 1/1 [==============================] - 0s 16ms/step
#  266.3  40.00  39.27   0.65
# 1/1 [==============================] - 0s 16ms/step
#  267.3  40.00  38.91   0.98
# 1/1 [==============================] - 0s 16ms/step
#  268.3  40.00  38.63   1.32
# 1/1 [==============================] - 0s 16ms/step
#  269.3  40.00  38.47   1.68
# 1/1 [==============================] - 0s 16ms/step
#  270.3  40.00  38.53   1.98
# 1/1 [==============================] - 0s 16ms/step
#  271.3  40.00  38.59   2.28
# 1/1 [==============================] - 0s 16ms/step
#  272.3  40.00  38.52   2.62
# 1/1 [==============================] - 0s 16ms/step
#  273.3  40.00  38.42   2.99
# 1/1 [==============================] - 0s 16ms/step
#  274.3  40.00  38.27   3.40
# 1/1 [==============================] - 0s 16ms/step
#  275.3  40.00  38.30   3.75
# 1/1 [==============================] - 0s 16ms/step
#  276.3  40.00  38.21   4.18
# 1/1 [==============================] - 0s 16ms/step
#  277.3  40.00  38.09   4.62
# 1/1 [==============================] - 0s 16ms/step
#  278.3  40.00  38.02   5.06
# 1/1 [==============================] - 0s 16ms/step
#  279.3  40.00  38.06   5.47
# 1/1 [==============================] - 0s 16ms/step
#  280.3  40.00  38.08   5.89
# 1/1 [==============================] - 0s 16ms/step
#  281.3  40.00  38.23   6.24
# 1/1 [==============================] - 0s 16ms/step
#  282.3  40.00  38.38   6.57
# 1/1 [==============================] - 0s 16ms/step
#  283.3  40.00  38.38   6.93
# 1/1 [==============================] - 0s 16ms/step
#  284.3  40.00  38.58   7.19
# 1/1 [==============================] - 0s 16ms/step
#  285.3  40.00  38.62   7.50
# 1/1 [==============================] - 0s 16ms/step
#  286.3  40.00  38.73   7.75
# 1/1 [==============================] - 0s 16ms/step
#  287.3  40.00  38.63   8.09
# 1/1 [==============================] - 0s 16ms/step
#  288.3  40.00  38.65   8.37
# 1/1 [==============================] - 0s 31ms/step
#  289.3  40.00  38.75   8.62
# 1/1 [==============================] - 0s 16ms/step
#  290.3  40.00  38.77   8.90
# 1/1 [==============================] - 0s 16ms/step
#  291.3  40.00  38.93   9.09
# 1/1 [==============================] - 0s 16ms/step
#  292.3  40.00  38.85   9.38
# 1/1 [==============================] - 0s 16ms/step
#  293.3  40.00  38.81   9.65
# 1/1 [==============================] - 0s 16ms/step
#  294.3  40.00  38.67   9.98
# 1/1 [==============================] - 0s 31ms/step
#  295.3  40.00  38.67  10.26
# 1/1 [==============================] - 0s 2ms/step
#  296.3  40.00  38.51  10.63
# 1/1 [==============================] - 0s 16ms/step
#  297.3  40.00  38.54  10.93
# 1/1 [==============================] - 0s 16ms/step
#  298.3  40.00  38.65  11.20
# 1/1 [==============================] - 0s 16ms/step
#  299.3  40.00  38.48  11.59
# 1/1 [==============================] - 0s 16ms/step
#  300.3  40.00  38.46  11.92
# 1/1 [==============================] - 0s 16ms/step
#  301.3  40.00  38.44  12.26
# 1/1 [==============================] - 0s 16ms/step
#  302.3  40.00  38.48  12.58
# 1/1 [==============================] - 0s 16ms/step
#  303.3  40.00  38.51  12.91
# 1/1 [==============================] - 0s 16ms/step
#  304.3  40.00  38.49  13.25
# 1/1 [==============================] - 0s 16ms/step
#  305.3  40.00  38.49  13.58
# 1/1 [==============================] - 0s 16ms/step
#  306.3  40.00  38.48  13.91
# 1/1 [==============================] - 0s 16ms/step
#  307.2  40.00  38.44  14.26
# 1/1 [==============================] - 0s 16ms/step
#  308.2  40.00  38.53  14.56
# 1/1 [==============================] - 0s 16ms/step
#  309.2  40.00  38.51  14.90
# 1/1 [==============================] - 0s 16ms/step
#  310.2  40.00  38.67  15.14
# 1/1 [==============================] - 0s 16ms/step
#  311.2  40.00  38.57  15.50
# 1/1 [==============================] - 0s 16ms/step
#  312.2  40.00  38.60  15.79
# 1/1 [==============================] - 0s 16ms/step
#  313.2  40.00  38.73  16.03
# 1/1 [==============================] - 0s 16ms/step
#  314.2  40.00  38.70  16.34
# 1/1 [==============================] - 0s 16ms/step
#  315.2  40.00  38.73  16.61
# 1/1 [==============================] - 0s 16ms/step
#  316.2  40.00  38.86  16.83
# 1/1 [==============================] - 0s 16ms/step
#  317.2  40.00  38.93  17.06
# 1/1 [==============================] - 0s 16ms/step
#  318.2  40.00  38.93  17.30
# 1/1 [==============================] - 0s 16ms/step
#  319.2  40.00  38.90  17.55
# 1/1 [==============================] - 0s 16ms/step
#  320.2  40.00  38.95  17.77
# 1/1 [==============================] - 0s 16ms/step
#  321.2  40.00  38.84  18.06
# 1/1 [==============================] - 0s 16ms/step
#  322.2  40.00  38.81  18.32
# 1/1 [==============================] - 0s 16ms/step
#  323.2  40.00  38.88  18.54
# 1/1 [==============================] - 0s 16ms/step
#  324.2  40.00  38.89  18.79
# 1/1 [==============================] - 0s 16ms/step
#  325.2  40.00  39.10  18.93
# 1/1 [==============================] - 0s 16ms/step
#  326.2  40.00  39.20  19.10
# 1/1 [==============================] - 0s 16ms/step
#  327.2  40.00  39.36  19.21
# 1/1 [==============================] - 0s 16ms/step
#  328.2  40.00  39.20  19.44
# 1/1 [==============================] - 0s 16ms/step
#  329.2  40.00  39.21  19.60
# 1/1 [==============================] - 0s 16ms/step
#  330.2  40.00  39.08  19.84
# 1/1 [==============================] - 0s 16ms/step
#  331.2  40.00  39.00  20.07
# 1/1 [==============================] - 0s 16ms/step
#  332.2  40.00  39.00  20.29
# 1/1 [==============================] - 0s 31ms/step
#  333.2  40.00  39.12  20.45
# 1/1 [==============================] - 0s 16ms/step
#  334.2  40.00  39.09  20.67
# 1/1 [==============================] - 0s 16ms/step
#  335.2  40.00  39.27  20.78
# 1/1 [==============================] - 0s 16ms/step
#  336.2  40.00  39.25  20.97
# 1/1 [==============================] - 0s 16ms/step
#  337.2  40.00  39.19  21.17
# 1/1 [==============================] - 0s 16ms/step
#  338.2  40.00  39.30  21.29
# 1/1 [==============================] - 0s 16ms/step
#  339.2  40.00  39.35  21.43
# 1/1 [==============================] - 0s 16ms/step
#  340.2  40.00  39.24  21.63
# 1/1 [==============================] - 0s 16ms/step
#  341.2  40.00  39.46  21.68
# 1/1 [==============================] - 0s 16ms/step
#  342.2  40.00  39.65  21.72
# 1/1 [==============================] - 0s 16ms/step
#  343.2  40.00  39.73  21.78
# 1/1 [==============================] - 0s 16ms/step
#  344.2  40.00  40.01  21.71
# 1/1 [==============================] - 0s 16ms/step
#  345.2  40.00  40.02  21.72
# 1/1 [==============================] - 0s 16ms/step
#  346.2  40.00  40.11  21.67
# 1/1 [==============================] - 0s 16ms/step
#  347.2  40.00  40.10  21.66
# 1/1 [==============================] - 0s 16ms/step
#  348.1  40.00  40.13  21.62
# 1/1 [==============================] - 0s 16ms/step
#  349.1  40.00  40.01  21.65
# 1/1 [==============================] - 0s 16ms/step
#  350.1  40.00  40.07  21.61
# 1/1 [==============================] - 0s 16ms/step
#  351.1  40.00  40.34  21.47
# 1/1 [==============================] - 0s 16ms/step
#  352.1  40.00  40.55  21.31
# 1/1 [==============================] - 0s 16ms/step
#  353.1  40.00  40.59  21.18
# 1/1 [==============================] - 0s 16ms/step
#  354.1  40.00  40.73  20.98
# 1/1 [==============================] - 0s 16ms/step
#  355.1  40.00  40.82  20.78
# 1/1 [==============================] - 0s 16ms/step
#  356.1  40.00  41.14  20.44
# 1/1 [==============================] - 0s 16ms/step
#  357.1  40.00  41.21  20.17
# 1/1 [==============================] - 0s 16ms/step
#  358.1  40.00  41.39  19.80
# Arduino disconnected successfully
# True

# %%
a.close()
a = itclab.iTCLab()
a.LED(0)
a.close()
# Out:
# Arduino disconnected successfully
# Opening connection
# iTCLab connected via Arduino on port COM5
# Arduino disconnected successfully
# True

# %%
a.close()
# Out:
# Arduino disconnected successfully
# True

# %%
[overshoot, settling_time, rise_time] = step_info(T1, tm, Tsp[0])
# Out:
# Overshoot: 18.52%
# Settling Time: 269.30 seconds
# Rising Time: 63.86 seconds

# %%
plt.figure(figsize=(10,4))
plt.plot(Tsp[:i],'k-',label='SP $(^oC)$')
plt.plot(T1[:i],'r-',label='$T_1$ $(^oC)$')
plt.plot(Q1[:i],'g-',label='$Q_{DL}$ (%)')
# Add overshoot label
plt.text(0.2, -0.2, 'Overshoot: {:.2f} %'.format(overshoot), ha='right', va='center', transform=plt.gca().transAxes, fontsize=12)
# add set point label
plt.text(0.2, -0.3, 'Set Point: {:.2f} °C'.format(Tsp[0]), ha='right', va='center', transform=plt.gca().transAxes, fontsize=12)


# Add rising time annotation
plt.axvline(x=rise_time, color='c', linestyle='--', label='Rising Time: {:.2f} seconds'.format(rise_time))
# add settling time annotation
plt.axvline(x=settling_time, color='m', linestyle='--', label='Settling Time: {:.2f} seconds'.format(settling_time))

plt.legend(fontsize=14, bbox_to_anchor=(1.04, 0.5), loc="center left", borderaxespad=0)
plt.ylim((0,100))
plt.xlabel('Time (s)',size=14)
plt.xticks(size=12)
plt.yticks(size=12)
plt.grid()
plt.show()

# %%
a.close()
a = itclab.iTCLab()
print(a.T1)
a.LED(0)
a.close()
# Out:
# Arduino disconnected successfully
# Opening connection
# iTCLab connected via Arduino on port COM5
# 30.4
# Arduino disconnected successfully
# True

# %%
# stop for 3 minutes code
for i in range(1,3):
    print(i)
    time.sleep(60)
# Out:
# 1
# 2

# %%
a = itclab.iTCLab()
print('LED On')
a.LED(100)
run_times = 7
loops = int(60.0*run_time)
tm = np.zeros(loops)
T1 = np.zeros(loops)
Tsp = np.zeros(loops)
Q1 = np.zeros(loops)
# Set point to 40 all the time
Tsp[:] = 40

start_time = time.time()
prev_time = start_time
ierr = 0.0
try:
    for i in range(1,loops):
        # Sleep time
        sleep_max = 1.0
        sleep = sleep_max - (time.time() - prev_time)
        if sleep>=0.01:
            time.sleep(sleep-0.01)
        else:
            time.sleep(0.01)

        # Record time and change in time
        t = time.time()
        dt = t - prev_time
        prev_time = t
        tm[i] = t - start_time

        # Read temperatures in C
        T1[i] = a.T1

        if i >= window:
            # Load data for model
            T1_m = T1[i-window:i]
            Tsp_m = Tsp[i-window:i]
            # Predict and store LSTM value for comparison
            Q1[i] = lstm(T1_m,Tsp_m)
        else:
            Q1[i] = lstm(T1[i],Tsp[i])

        a.Q1(Q1[i])
        a.Q2(0.0)
        print(('{:6.1f} {:6.2f} {:6.2f} ' + \
               '{:6.2f} ').format( \
            tm[i],Tsp[i],T1[i], \
            Q1[i]))

except KeyboardInterrupt:
    # Disconnect from Arduino
    a.Q1(0)
    a.Q2(0)
    print('Shutting down')
    a.close()


# Make sure serial connection still closes when there's an error
except:
    # Disconnect from Arduino
    a.Q1(0)
    a.Q2(0)
    print('Error: Shutting down')
    a.close()

    raise

a.close()
# Out:
# Opening connection
# iTCLab connected via Arduino on port COM5
# LED On
# 1/1 [==============================] - 0s 16ms/step
#    1.0  40.00  30.34  60.70
# 1/1 [==============================] - 0s 16ms/step
#    2.0  40.00  30.34  60.70
# 1/1 [==============================] - 0s 16ms/step
#    3.0  40.00  30.30  60.74
# 1/1 [==============================] - 0s 16ms/step
#    4.0  40.00  30.27  60.77
# 1/1 [==============================] - 0s 16ms/step
#    5.0  40.00  30.38  60.65
# 1/1 [==============================] - 0s 16ms/step
#    6.0  40.00  30.38  60.65
# 1/1 [==============================] - 0s 16ms/step
#    7.0  40.00  30.45  60.57
# 1/1 [==============================] - 0s 16ms/step
#    8.0  40.00  30.43  60.60
# 1/1 [==============================] - 0s 16ms/step
#    9.0  40.00  30.43  60.60
# 1/1 [==============================] - 0s 16ms/step
#   10.0  40.00  30.46  60.56
# 1/1 [==============================] - 0s 16ms/step
#   11.0  40.00  30.60  60.41
# 1/1 [==============================] - 0s 16ms/step
#   12.0  40.00  30.60  60.41
# 1/1 [==============================] - 0s 16ms/step
#   13.0  40.00  30.63  60.38
# 1/1 [==============================] - 0s 16ms/step
#   14.0  40.00  30.80  60.19
# 1/1 [==============================] - 0s 16ms/step
#   15.0  40.00  30.90  81.66
# 1/1 [==============================] - 0s 16ms/step
#   16.0  40.00  30.81  80.00
# 1/1 [==============================] - 0s 31ms/step
#   17.0  40.00  30.97  79.87
# 1/1 [==============================] - 0s 16ms/step
#   18.0  40.00  31.04  79.55
# 1/1 [==============================] - 0s 16ms/step
#   19.0  40.00  31.14  79.28
# 1/1 [==============================] - 0s 16ms/step
#   20.0  40.00  31.25  78.96
# 1/1 [==============================] - 0s 31ms/step
#   21.0  40.00  31.41  78.60
# 1/1 [==============================] - 0s 16ms/step
#   22.0  40.00  31.48  78.14
# 1/1 [==============================] - 0s 16ms/step
#   23.0  40.00  31.59  77.74
# 1/1 [==============================] - 0s 16ms/step
#   24.0  40.00  31.65  77.29
# 1/1 [==============================] - 0s 16ms/step
#   25.0  40.00  31.72  76.90
# 1/1 [==============================] - 0s 16ms/step
#   26.0  40.00  32.04  76.53
# 1/1 [==============================] - 0s 16ms/step
#   27.0  40.00  32.08  75.86
# 1/1 [==============================] - 0s 16ms/step
#   28.0  40.00  32.28  75.37
# 1/1 [==============================] - 0s 31ms/step
#   29.0  40.00  32.41  74.71
# 1/1 [==============================] - 0s 16ms/step
#   30.0  40.00  32.43  74.09
#   68.9  40.00  37.16  49.19
# 1/1 [==============================] - 0s 19ms/step
#   69.9  40.00  37.19  48.69
# 1/1 [==============================] - 0s 16ms/step
#   70.9  40.00  37.32  48.31
# 1/1 [==============================] - 0s 16ms/step
#   71.9  40.00  37.44  47.84
# 1/1 [==============================] - 0s 16ms/step
#   72.9  40.00  37.38  47.34
# 1/1 [==============================] - 0s 16ms/step
#   73.9  40.00  37.66  47.05
# 1/1 [==============================] - 0s 16ms/step
#   74.9  40.00  37.71  46.42
# 1/1 [==============================] - 0s 16ms/step
#   75.9  40.00  37.73  45.90
# 1/1 [==============================] - 0s 16ms/step
#   76.9  40.00  37.84  45.48
# 1/1 [==============================] - 0s 31ms/step
#   77.9  40.00  37.90  45.00
# 1/1 [==============================] - 0s 31ms/step
#   78.9  40.00  38.12  44.59
# 1/1 [==============================] - 0s 16ms/step
#   79.9  40.00  38.04  43.97
# 1/1 [==============================] - 0s 16ms/step
#   80.9  40.00  38.21  43.64
# 1/1 [==============================] - 0s 16ms/step
#   81.9  40.00  38.28  43.16
# 1/1 [==============================] - 0s 16ms/step
#   82.9  40.00  38.37  42.73
# 1/1 [==============================] - 0s 16ms/step
#   83.9  40.00  38.41  42.28
# 1/1 [==============================] - 0s 16ms/step
#   84.9  40.00  38.55  41.90
# 1/1 [==============================] - 0s 31ms/step
#   85.9  40.00  38.65  41.42
# 1/1 [==============================] - 0s 16ms/step
#   86.9  40.00  38.71  40.94
# 1/1 [==============================] - 0s 31ms/step
#   87.9  40.00  38.94  40.51
# 1/1 [==============================] - 0s 11ms/step
#   88.8  40.00  38.81  39.85
# 1/1 [==============================] - 0s 16ms/step
#   89.8  40.00  38.99  39.59
# 1/1 [==============================] - 0s 16ms/step
#   90.8  40.00  39.08  39.16
# 1/1 [==============================] - 0s 16ms/step
#   91.8  40.00  39.10  38.73
# 1/1 [==============================] - 0s 16ms/step
#   92.8  40.00  39.06  38.39
# 1/1 [==============================] - 0s 16ms/step
#   93.8  40.00  39.05  38.21
# 1/1 [==============================] - 0s 16ms/step
#   94.8  40.00  38.96  38.12
# 1/1 [==============================] - 0s 16ms/step
#   95.8  40.00  39.26  38.18
# 1/1 [==============================] - 0s 16ms/step
#   96.8  40.00  39.35  37.79
# 1/1 [==============================] - 0s 16ms/step
#   97.8  40.00  39.53  37.35
# 1/1 [==============================] - 0s 16ms/step
#   98.8  40.00  39.60  36.74
# 1/1 [==============================] - 0s 16ms/step
#   99.8  40.00  39.73  36.20
# 1/1 [==============================] - 0s 16ms/step
#  100.8  40.00  39.75  35.64
# 1/1 [==============================] - 0s 31ms/step
#  101.8  40.00  39.80  35.26
# 1/1 [==============================] - 0s 16ms/step
#  102.8  40.00  39.95  34.96
# 1/1 [==============================] - 0s 31ms/step
#  103.8  40.00  40.11  34.58
# 1/1 [==============================] - 0s 16ms/step
#  104.8  40.00  40.29  34.10
# 1/1 [==============================] - 0s 16ms/step
#  105.8  40.00  40.41  33.52
# 1/1 [==============================] - 0s 16ms/step
#  106.8  40.00  40.44  32.94
# 1/1 [==============================] - 0s 16ms/step
#  107.8  40.00  40.67  32.51
# 1/1 [==============================] - 0s 16ms/step
#  108.8  40.00  40.75  31.91
# 1/1 [==============================] - 0s 16ms/step
#  109.8  40.00  40.74  31.39
# 1/1 [==============================] - 0s 16ms/step
#  110.8  40.00  40.81  31.05
# 1/1 [==============================] - 0s 16ms/step
#  111.8  40.00  40.89  30.76
# 1/1 [==============================] - 0s 16ms/step
#  112.8  40.00  40.94  30.48
# 1/1 [==============================] - 0s 31ms/step
#  113.8  40.00  40.68  30.22
# 1/1 [==============================] - 0s 31ms/step
#  114.8  40.00  40.26  30.39
# 1/1 [==============================] - 0s 16ms/step
#  115.8  40.00  39.68  31.11
# 1/1 [==============================] - 0s 16ms/step
#  116.8  40.00  39.13  32.43
# 1/1 [==============================] - 0s 31ms/step
#  117.8  40.00  38.78  34.12
# 1/1 [==============================] - 0s 16ms/step
#  118.8  40.00  38.88  35.77
# 1/1 [==============================] - 0s 31ms/step
#  119.8  40.00  39.09  36.71
# 1/1 [==============================] - 0s 31ms/step
#  120.8  40.00  39.35  36.89
# 1/1 [==============================] - 0s 16ms/step
#  121.8  40.00  39.65  36.44
# 1/1 [==============================] - 0s 16ms/step
#  122.8  40.00  39.79  35.54
# 1/1 [==============================] - 0s 16ms/step
#  123.8  40.00  39.87  34.66
# 1/1 [==============================] - 0s 16ms/step
#  124.7  40.00  39.96  34.00
# 1/1 [==============================] - 0s 16ms/step
#  125.7  40.00  39.99  33.56
# 1/1 [==============================] - 0s 16ms/step
#  126.7  40.00  40.19  33.40
# 1/1 [==============================] - 0s 31ms/step
#  127.7  40.00  40.43  33.17
# 1/1 [==============================] - 0s 16ms/step
#  128.7  40.00  40.47  32.78
# 1/1 [==============================] - 0s 16ms/step
#  129.7  40.00  40.61  32.49
# 1/1 [==============================] - 0s 16ms/step
#  130.7  40.00  40.77  32.10
# 1/1 [==============================] - 0s 16ms/step
#  131.7  40.00  40.82  31.60
# 1/1 [==============================] - 0s 16ms/step
#  132.7  40.00  41.00  31.13
# 1/1 [==============================] - 0s 16ms/step
#  133.7  40.00  41.01  30.55
# 1/1 [==============================] - 0s 31ms/step
#  134.7  40.00  41.12  30.13
# 1/1 [==============================] - 0s 16ms/step
#  135.7  40.00  40.77  29.72
# 1/1 [==============================] - 0s 16ms/step
#  136.7  40.00  40.57  29.93
# 1/1 [==============================] - 0s 32ms/step
#  137.7  40.00  40.48  30.41
# 1/1 [==============================] - 0s 31ms/step
#  138.7  40.00  40.59  30.89
# 1/1 [==============================] - 0s 16ms/step
#  139.7  40.00  40.80  31.05
# 1/1 [==============================] - 0s 31ms/step
#  140.7  40.00  40.93  30.77
# 1/1 [==============================] - 0s 16ms/step
#  141.7  40.00  41.06  30.28
# 1/1 [==============================] - 0s 16ms/step
#  142.7  40.00  41.13  29.70
# 1/1 [==============================] - 0s 31ms/step
#  143.7  40.00  41.16  29.20
# 1/1 [==============================] - 0s 16ms/step
#  144.7  40.00  40.82  28.85
# 1/1 [==============================] - 0s 31ms/step
#  145.7  40.00  40.19  29.14
# 1/1 [==============================] - 0s 16ms/step
#  146.7  40.00  40.17  30.30
# 1/1 [==============================] - 0s 16ms/step
#  147.7  40.00  40.42  31.26
# 1/1 [==============================] - 0s 7ms/step
#  148.7  40.00  40.62  31.58
# 1/1 [==============================] - 0s 16ms/step
#  149.7  40.00  40.99  31.40
# 1/1 [==============================] - 0s 16ms/step
#  150.7  40.00  41.02  30.63
# 1/1 [==============================] - 0s 16ms/step
#  151.7  40.00  41.19  29.91
# 1/1 [==============================] - 0s 16ms/step
#  152.7  40.00  41.34  29.16
# 1/1 [==============================] - 0s 16ms/step
#  153.7  40.00  41.45  28.50
# 1/1 [==============================] - 0s 16ms/step
#  154.7  40.00  40.89  28.00
# 1/1 [==============================] - 0s 16ms/step
#  155.7  40.00  40.97  28.52
# 1/1 [==============================] - 0s 16ms/step
#  156.7  40.00  41.22  28.94
# 1/1 [==============================] - 0s 16ms/step
#  157.7  40.00  41.35  28.97
# 1/1 [==============================] - 0s 31ms/step
#  158.7  40.00  41.63  28.76
# 1/1 [==============================] - 0s 16ms/step
#  159.7  40.00  41.59  28.17
# 1/1 [==============================] - 0s 31ms/step
#  160.7  40.00  41.80  27.73
# 1/1 [==============================] - 0s 31ms/step
#  161.7  40.00  41.74  27.11
# 1/1 [==============================] - 0s 21ms/step
#  162.7  40.00  41.97  26.78
# 1/1 [==============================] - 0s 31ms/step
#  163.6  40.00  42.07  26.33
# 1/1 [==============================] - 0s 16ms/step
#  164.6  40.00  41.66  25.92
# 1/1 [==============================] - 0s 31ms/step
#  165.6  40.00  40.88  26.23
# 1/1 [==============================] - 0s 16ms/step
#  166.6  40.00  40.51  27.54
# 1/1 [==============================] - 0s 16ms/step
#  167.7  40.00  40.28  29.07
# 1/1 [==============================] - 0s 16ms/step
#  168.6  40.00  40.33  30.44
# 1/1 [==============================] - 0s 16ms/step
#  169.6  40.00  40.48  31.22
# 1/1 [==============================] - 0s 16ms/step
#  170.6  40.00  40.59  31.32
# 1/1 [==============================] - 0s 16ms/step
#  171.6  40.00  40.62  31.02
# 1/1 [==============================] - 0s 16ms/step
#  172.6  40.00  40.85  30.63
# 1/1 [==============================] - 0s 16ms/step
#  173.6  40.00  41.08  30.00
# 1/1 [==============================] - 0s 16ms/step
#  174.6  40.00  41.20  29.28
# 1/1 [==============================] - 0s 16ms/step
#  175.6  40.00  41.23  28.67
# 1/1 [==============================] - 0s 16ms/step
#  176.6  40.00  40.72  28.33
# 1/1 [==============================] - 0s 31ms/step
#  177.6  40.00  40.56  28.93
# 1/1 [==============================] - 0s 16ms/step
#  178.6  40.00  40.17  29.76
# 1/1 [==============================] - 0s 16ms/step
#  179.6  40.00  40.15  30.98
# 1/1 [==============================] - 0s 16ms/step
#  180.6  40.00  40.02  31.85
# 1/1 [==============================] - 0s 16ms/step
#  181.6  40.00  40.02  32.51
# 1/1 [==============================] - 0s 31ms/step
#  182.6  40.00  40.02  32.82
# 1/1 [==============================] - 0s 16ms/step
#  183.6  40.00  40.25  32.90
# 1/1 [==============================] - 0s 16ms/step
#  184.6  40.00  40.35  32.54
# 1/1 [==============================] - 0s 16ms/step
#  185.6  40.00  40.55  32.08
# 1/1 [==============================] - 0s 16ms/step
#  186.6  40.00  40.81  31.46
# 1/1 [==============================] - 0s 31ms/step
#  187.6  40.00  41.16  30.69
# 1/1 [==============================] - 0s 16ms/step
#  188.6  40.00  41.56  29.75
# 1/1 [==============================] - 0s 16ms/step
#  189.6  40.00  41.70  28.64
# 1/1 [==============================] - 0s 16ms/step
#  190.6  40.00  41.37  27.80
# 1/1 [==============================] - 0s 16ms/step
#  191.6  40.00  41.04  27.82
# 1/1 [==============================] - 0s 16ms/step
#  192.6  40.00  40.90  28.42
# 1/1 [==============================] - 0s 16ms/step
#  193.6  40.00  41.09  29.16
# 1/1 [==============================] - 0s 16ms/step
#  194.6  40.00  41.23  29.42
# 1/1 [==============================] - 0s 16ms/step
#  195.6  40.00  41.47  29.30
# 1/1 [==============================] - 0s 16ms/step
#  196.6  40.00  41.46  28.76
# 1/1 [==============================] - 0s 22ms/step
#  197.6  40.00  41.59  28.26
# 1/1 [==============================] - 0s 16ms/step
#  198.6  40.00  41.80  27.71
# 1/1 [==============================] - 0s 16ms/step
#  199.6  40.00  41.87  27.05
# 1/1 [==============================] - 0s 16ms/step
#  200.6  40.00  41.88  26.53
# 1/1 [==============================] - 0s 16ms/step
#  201.6  40.00  41.58  26.22
# 1/1 [==============================] - 0s 16ms/step
#  202.6  40.00  41.22  26.48
# 1/1 [==============================] - 0s 16ms/step
#  203.6  40.00  41.33  27.25
# 1/1 [==============================] - 0s 16ms/step
#  204.6  40.00  41.44  27.74
# 1/1 [==============================] - 0s 16ms/step
#  205.6  40.00  41.66  27.90
# 1/1 [==============================] - 0s 16ms/step
#  206.6  40.00  41.79  27.59
# 1/1 [==============================] - 0s 16ms/step
#  207.6  40.00  41.99  27.07
# 1/1 [==============================] - 0s 16ms/step
#  208.6  40.00  42.17  26.38
# 1/1 [==============================] - 0s 16ms/step
#  209.6  40.00  41.99  25.66
# 1/1 [==============================] - 0s 16ms/step
#  210.6  40.00  40.91  25.44
# 1/1 [==============================] - 0s 16ms/step
#  211.6  40.00  40.70  26.82
# 1/1 [==============================] - 0s 16ms/step
#  212.6  40.00  40.57  28.27
# 1/1 [==============================] - 0s 16ms/step
#  213.6  40.00  40.78  29.50
# 1/1 [==============================] - 0s 16ms/step
#  214.6  40.00  40.93  29.99
# 1/1 [==============================] - 0s 16ms/step
#  215.6  40.00  41.13  29.93
# 1/1 [==============================] - 0s 16ms/step
#  216.6  40.00  41.50  29.42
# 1/1 [==============================] - 0s 16ms/step
#  217.6  40.00  41.61  28.42
# 1/1 [==============================] - 0s 16ms/step
#  218.6  40.00  41.82  27.50
# 1/1 [==============================] - 0s 16ms/step
#  219.6  40.00  41.82  26.65
# 1/1 [==============================] - 0s 31ms/step
#  220.6  40.00  41.95  26.19
# 1/1 [==============================] - 0s 31ms/step
#  221.6  40.00  42.17  25.89
# 1/1 [==============================] - 0s 16ms/step
#  222.6  40.00  42.26  25.53
# 1/1 [==============================] - 0s 16ms/step
#  223.6  40.00  42.33  25.28
# 1/1 [==============================] - 0s 26ms/step
#  224.6  40.00  42.56  25.09
# 1/1 [==============================] - 0s 16ms/step
#  225.6  40.00  42.66  24.71
# 1/1 [==============================] - 0s 31ms/step
#  226.6  40.00  42.63  24.26
# 1/1 [==============================] - 0s 16ms/step
#  227.6  40.00  42.47  23.99
# 1/1 [==============================] - 0s 16ms/step
#  228.6  40.00  42.45  24.03
# 1/1 [==============================] - 0s 16ms/step
#  229.6  40.00  42.37  24.13
# 1/1 [==============================] - 0s 16ms/step
#  230.6  40.00  42.49  24.32
# 1/1 [==============================] - 0s 16ms/step
#  231.6  40.00  42.52  24.29
# 1/1 [==============================] - 0s 16ms/step
#  232.6  40.00  42.62  24.18
# 1/1 [==============================] - 0s 16ms/step
#  233.6  40.00  42.71  23.93
# 1/1 [==============================] - 0s 31ms/step
#  234.6  40.00  42.80  23.61
# 1/1 [==============================] - 0s 16ms/step
#  235.6  40.00  42.76  23.25
# 1/1 [==============================] - 0s 16ms/step
#  236.6  40.00  42.89  23.07
# 1/1 [==============================] - 0s 16ms/step
#  237.6  40.00  42.89  22.83
# 1/1 [==============================] - 0s 16ms/step
#  238.6  40.00  42.80  22.70
# 1/1 [==============================] - 0s 16ms/step
#  239.6  40.00  42.89  22.75
# 1/1 [==============================] - 0s 16ms/step
#  240.6  40.00  43.01  22.73
# 1/1 [==============================] - 0s 16ms/step
#  241.6  40.00  42.98  22.58
# 1/1 [==============================] - 0s 16ms/step
#  242.6  40.00  43.08  22.50
# 1/1 [==============================] - 0s 16ms/step
#  243.6  40.00  43.00  22.31
# 1/1 [==============================] - 0s 16ms/step
#  244.6  40.00  43.08  22.28
# 1/1 [==============================] - 0s 32ms/step
#  245.6  40.00  43.06  22.18
# 1/1 [==============================] - 0s 16ms/step
#  246.6  40.00  42.75  22.14
# 1/1 [==============================] - 0s 16ms/step
#  247.6  40.00  42.33  22.49
# 1/1 [==============================] - 0s 16ms/step
#  248.6  40.00  42.02  23.30
# 1/1 [==============================] - 0s 16ms/step
#  249.6  40.00  42.08  24.28
# 1/1 [==============================] - 0s 16ms/step
#  250.6  40.00  42.38  24.88
# 1/1 [==============================] - 0s 31ms/step
#  251.6  40.00  42.68  24.81
# 1/1 [==============================] - 0s 16ms/step
#  252.6  40.00  42.00  24.20
# 1/1 [==============================] - 0s 16ms/step
#  253.6  40.00  41.15  24.47
# 1/1 [==============================] - 0s 16ms/step
#  254.5  40.00  40.95  25.81
# 1/1 [==============================] - 0s 31ms/step
#  255.5  40.00  40.68  27.17
# 1/1 [==============================] - 0s 16ms/step
#  256.5  40.00  40.27  28.48
# 1/1 [==============================] - 0s 16ms/step
#  257.5  40.00  39.93  29.85
# 1/1 [==============================] - 0s 16ms/step
#  258.5  40.00  39.70  31.16
# 1/1 [==============================] - 0s 31ms/step
#  259.5  40.00  39.81  32.28
# 1/1 [==============================] - 0s 16ms/step
#  260.5  40.00  40.20  32.81
# 1/1 [==============================] - 0s 16ms/step
#  261.5  40.00  40.46  32.50
# 1/1 [==============================] - 0s 16ms/step
#  262.5  40.00  40.71  31.75
# 1/1 [==============================] - 0s 31ms/step
#  263.5  40.00  40.79  30.79
# 1/1 [==============================] - 0s 16ms/step
#  264.5  40.00  41.14  30.03
# 1/1 [==============================] - 0s 11ms/step
#  265.5  40.00  41.24  29.19
# 1/1 [==============================] - 0s 16ms/step
#  266.5  40.00  41.32  28.68
# 1/1 [==============================] - 0s 31ms/step
#  267.5  40.00  41.38  28.43
# 1/1 [==============================] - 0s 16ms/step
#  268.5  40.00  41.63  28.31
# 1/1 [==============================] - 0s 16ms/step
#  269.5  40.00  41.73  27.95
# 1/1 [==============================] - 0s 16ms/step
#  270.5  40.00  41.76  27.61
# 1/1 [==============================] - 0s 16ms/step
#  271.5  40.00  41.84  27.35
# 1/1 [==============================] - 0s 16ms/step
#  272.5  40.00  41.93  27.05
# 1/1 [==============================] - 0s 16ms/step
#  273.5  40.00  42.05  26.71
# 1/1 [==============================] - 0s 16ms/step
#  274.5  40.00  42.17  26.29
# 1/1 [==============================] - 0s 16ms/step
#  275.5  40.00  42.25  25.84
# 1/1 [==============================] - 0s 16ms/step
#  276.5  40.00  42.44  25.43
# 1/1 [==============================] - 0s 16ms/step
#  277.5  40.00  42.53  24.92
# 1/1 [==============================] - 0s 16ms/step
#  278.5  40.00  42.46  24.47
# 1/1 [==============================] - 0s 16ms/step
#  279.5  40.00  42.49  24.27
# 1/1 [==============================] - 0s 16ms/step
#  280.5  40.00  42.60  24.16
# 1/1 [==============================] - 0s 16ms/step
#  281.5  40.00  42.81  23.99
# 1/1 [==============================] - 0s 16ms/step
#  282.5  40.00  42.88  23.60
# 1/1 [==============================] - 0s 31ms/step
#  283.5  40.00  43.04  23.23
# 1/1 [==============================] - 0s 16ms/step
#  284.5  40.00  42.79  22.79
# 1/1 [==============================] - 0s 23ms/step
#  285.5  40.00  42.02  22.80
# 1/1 [==============================] - 0s 16ms/step
#  286.5  40.00  42.24  23.83
# 1/1 [==============================] - 0s 16ms/step
#  287.5  40.00  41.83  24.41
# 1/1 [==============================] - 0s 16ms/step
#  288.5  40.00  41.97  25.26
# 1/1 [==============================] - 0s 16ms/step
#  289.5  40.00  41.75  25.62
# 1/1 [==============================] - 0s 16ms/step
#  290.5  40.00  41.90  26.01
# 1/1 [==============================] - 0s 16ms/step
#  291.5  40.00  42.07  25.99
# 1/1 [==============================] - 0s 16ms/step
#  292.5  40.00  41.95  25.65
# 1/1 [==============================] - 0s 16ms/step
#  293.5  40.00  42.19  25.49
# 1/1 [==============================] - 0s 16ms/step
#  294.5  40.00  42.37  25.07
# 1/1 [==============================] - 0s 16ms/step
#  295.5  40.00  42.50  24.56
# 1/1 [==============================] - 0s 31ms/step
#  296.5  40.00  42.61  24.08
# 1/1 [==============================] - 0s 16ms/step
#  297.5  40.00  42.46  23.69
# 1/1 [==============================] - 0s 16ms/step
#  298.5  40.00  42.59  23.70
# 1/1 [==============================] - 0s 16ms/step
#  299.5  40.00  42.59  23.68
# 1/1 [==============================] - 0s 16ms/step
#  300.5  40.00  42.61  23.72
# 1/1 [==============================] - 0s 16ms/step
#  301.5  40.00  42.62  23.70
# 1/1 [==============================] - 0s 16ms/step
#  302.5  40.00  42.40  23.70
# 1/1 [==============================] - 0s 16ms/step
#  303.5  40.00  41.47  23.95
# 1/1 [==============================] - 0s 12ms/step
#  304.5  40.00  41.29  25.30
# 1/1 [==============================] - 0s 16ms/step
#  305.5  40.00  40.77  26.56
# 1/1 [==============================] - 0s 31ms/step
#  306.5  40.00  40.63  28.05
# 1/1 [==============================] - 0s 16ms/step
#  307.5  40.00  40.45  29.20
# 1/1 [==============================] - 0s 16ms/step
#  308.5  40.00  40.54  30.07
# 1/1 [==============================] - 0s 16ms/step
#  309.5  40.00  40.76  30.38
# 1/1 [==============================] - 0s 16ms/step
#  310.5  40.00  40.92  30.13
# 1/1 [==============================] - 0s 16ms/step
#  311.5  40.00  41.10  29.59
# 1/1 [==============================] - 0s 31ms/step
#  312.5  40.00  41.38  28.91
# 1/1 [==============================] - 0s 31ms/step
#  313.5  40.00  41.71  28.08
# 1/1 [==============================] - 0s 16ms/step
#  314.5  40.00  41.87  27.15
# 1/1 [==============================] - 0s 31ms/step
#  315.5  40.00  41.97  26.43
# 1/1 [==============================] - 0s 16ms/step
#  316.5  40.00  42.20  25.99
# 1/1 [==============================] - 0s 16ms/step
#  317.5  40.00  42.51  25.57
# 1/1 [==============================] - 0s 31ms/step
#  318.5  40.00  42.56  25.00
# 1/1 [==============================] - 0s 16ms/step
#  319.5  40.00  42.35  24.57
# 1/1 [==============================] - 0s 16ms/step
#  320.5  40.00  41.49  24.62
# 1/1 [==============================] - 0s 16ms/step
#  321.5  40.00  41.26  25.81
# 1/1 [==============================] - 0s 16ms/step
#  322.5  40.00  41.27  27.04
# 1/1 [==============================] - 0s 16ms/step
#  323.5  40.00  41.32  27.86
# 1/1 [==============================] - 0s 16ms/step
#  324.5  40.00  41.26  28.20
# 1/1 [==============================] - 0s 16ms/step
#  325.5  40.00  41.36  28.32
# 1/1 [==============================] - 0s 31ms/step
#  326.5  40.00  41.15  28.11
# 1/1 [==============================] - 0s 16ms/step
#  327.5  40.00  41.18  28.12
# 1/1 [==============================] - 0s 16ms/step
#  328.4  40.00  41.06  28.07
# 1/1 [==============================] - 0s 16ms/step
#  329.4  40.00  41.10  28.21
# 1/1 [==============================] - 0s 16ms/step
#  330.4  40.00  41.08  28.29
# 1/1 [==============================] - 0s 16ms/step
#  331.4  40.00  40.69  28.39
# 1/1 [==============================] - 0s 16ms/step
#  332.4  40.00  40.64  29.01
# 1/1 [==============================] - 0s 31ms/step
#  333.4  40.00  40.62  29.59
# 1/1 [==============================] - 0s 16ms/step
#  334.4  40.00  40.82  30.06
# 1/1 [==============================] - 0s 16ms/step
#  335.4  40.00  41.10  30.07
# 1/1 [==============================] - 0s 16ms/step
#  336.4  40.00  41.54  29.58
# 1/1 [==============================] - 0s 16ms/step
#  337.4  40.00  41.69  28.55
# 1/1 [==============================] - 0s 16ms/step
#  338.4  40.00  41.83  27.59
# 1/1 [==============================] - 0s 16ms/step
#  339.4  40.00  42.07  26.82
# 1/1 [==============================] - 0s 16ms/step
#  340.4  40.00  42.29  26.09
# 1/1 [==============================] - 0s 16ms/step
#  341.4  40.00  42.38  25.44
# 1/1 [==============================] - 0s 16ms/step
#  342.4  40.00  42.52  24.98
# 1/1 [==============================] - 0s 16ms/step
#  343.4  40.00  42.73  24.60
# 1/1 [==============================] - 0s 31ms/step
#  344.4  40.00  43.05  24.14
# 1/1 [==============================] - 0s 16ms/step
#  345.4  40.00  43.18  23.47
# 1/1 [==============================] - 0s 31ms/step
#  346.4  40.00  43.34  22.85
# 1/1 [==============================] - 0s 16ms/step
#  347.4  40.00  43.40  22.24
# 1/1 [==============================] - 0s 16ms/step
#  348.4  40.00  43.53  21.79
# 1/1 [==============================] - 0s 31ms/step
#  349.4  40.00  43.65  21.37
# 1/1 [==============================] - 0s 16ms/step
#  350.4  40.00  43.70  20.98
# 1/1 [==============================] - 0s 16ms/step
#  351.4  40.00  43.86  20.70
# 1/1 [==============================] - 0s 16ms/step
#  352.4  40.00  43.99  20.35
# 1/1 [==============================] - 0s 31ms/step
#  353.4  40.00  44.11  19.98
# 1/1 [==============================] - 0s 31ms/step
#  354.4  40.00  44.13  19.59
# 1/1 [==============================] - 0s 16ms/step
#  355.4  40.00  44.31  19.31
# 1/1 [==============================] - 0s 16ms/step
#  356.4  40.00  44.30  18.96
# 1/1 [==============================] - 0s 31ms/step
#  357.4  40.00  44.54  18.74
# 1/1 [==============================] - 0s 16ms/step
#  358.4  40.00  44.39  18.36
# Arduino disconnected successfully
# True

# %%
a.close()
# Out:
# Arduino disconnected successfully
# True

# %%
[overshoot, settling_time, rise_time] = step_info(T1, tm, Tsp[0])
# Out:
# Overshoot: 11.35%
# Settling Time: 237.62 seconds
# Rising Time: 55.89 seconds

# %%
plt.figure(figsize=(10,4))
plt.plot(Tsp[:i],'k-',label='SP $(^oC)$')
plt.plot(T1[:i],'r-',label='$T_1$ $(^oC)$')
plt.plot(Q1[:i],'g-',label='$Q_{LSTM}$ (%)')
# Add overshoot label
plt.text(0.2, -0.2, 'Overshoot: {:.2f} %'.format(overshoot), ha='right', va='center', transform=plt.gca().transAxes, fontsize=12)
# add set point label
plt.text(0.2, -0.3, 'Set Point: {:.2f} °C'.format(Tsp[0]), ha='right', va='center', transform=plt.gca().transAxes, fontsize=12)


# Add rising time annotation
plt.axvline(x=rise_time, color='c', linestyle='--', label='Rising Time: {:.2f} seconds'.format(rise_time))
# add settling time annotation
plt.axvline(x=settling_time, color='m', linestyle='--', label='Settling Time: {:.2f} seconds'.format(settling_time))

plt.legend(fontsize=14, bbox_to_anchor=(1.04, 0.5), loc="center left", borderaxespad=0)
plt.ylim((0,100))
plt.xlabel('Time (s)',size=14)
plt.xticks(size=12)
plt.yticks(size=12)
plt.grid()
plt.show()
